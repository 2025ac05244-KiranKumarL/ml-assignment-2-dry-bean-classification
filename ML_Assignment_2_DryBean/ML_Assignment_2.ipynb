# %% [markdown]
# # Machine Learning Assignment 2 — Dry Bean Classification
#
# This notebook trains the five classification models explicitly named in the assignment PDF and saves the artifacts required by the Streamlit app.

# %%
# Install only if your environment does not already have these packages
# !pip install -r requirements.txt

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print('Project root:', PROJECT_ROOT)

# %%
from ml_utils import load_dry_bean_dataset, FEATURE_COLUMNS, TARGET_COLUMN
df = load_dry_bean_dataset(PROJECT_ROOT)
print('Dataset shape:', df.shape)
print('Number of features:', len(FEATURE_COLUMNS))
print('Target:', TARGET_COLUMN)
display(df.head())
display(df[TARGET_COLUMN].value_counts())

# %% [markdown]
# ## Train all models and generate the required artifacts
#
# The training function performs the 80/20 stratified split, trains all models, calculates Accuracy, AUC, Precision, Recall, F1 and MCC, saves all model files, generates `test_data.csv`, and creates the comparison table.

# %%
from model.train_models import main
main()

# %%
import pandas as pd
comparison = pd.read_csv(PROJECT_ROOT / 'model_comparison.csv')
display(comparison)

# %% [markdown]
# ## Next Step
#
# After the training completes successfully, run:
#
# ```bash
# streamlit run app.py
# ```
#
# Use the generated `test_data.csv` in the Streamlit app and capture the required BITS Virtual Lab screenshot for the final PDF.
